# %%
from fastf1.ergast import Ergast
import pandas as pd
ergast = Ergast(result_type='pandas', auto_cast=True)

seasons = ergast.get_race_results(season=2021, limit=1000)

for i in seasons.content:
    # https://docs.fastf1.dev/ergast.html#fastf1.ergast.Ergast.get_race_results
    print(i)
# Out:
#     number  position positionText  points  grid  laps    status  \
# 0       44         1            1    25.0     2    56  Finished
# 1       33         2            2    18.0     1    56  Finished
# 2       77         3            3    16.0     3    56  Finished
# 3        4         4            4    12.0     7    56  Finished
# 4       11         5            5    10.0     0    56  Finished
# 5       16         6            6     8.0     4    56  Finished
# 6        3         7            7     6.0     6    56  Finished
# 7       55         8            8     4.0     8    56  Finished
# 8       22         9            9     2.0    13    56  Finished
# 9       18        10           10     1.0    10    56  Finished
# 10       7        11           11     0.0    14    56  Finished
# 11      99        12           12     0.0    12    55    +1 Lap
# 12      31        13           13     0.0    16    55    +1 Lap
# 13      63        14           14     0.0    15    55    +1 Lap
# ...
